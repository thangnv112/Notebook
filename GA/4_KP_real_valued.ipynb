# %% [markdown]
# ### Bài toán cái túi (Knapsack Problem)
# Đầu vào:
# - Danh sách giá trị của từng đồ vật $profit$
# - Danh sách cân nặng tương ứng $weight$
# - Trọng lượng có thể mang theo $capacity$
#
# Đầu ra:
# - Phương án mang đồ vật

# %%
import numpy as np # type: ignore
import random
import copy
import matplotlib.pyplot as plt # type: ignore

# %%
class Problem:
    def __init__(self, profit, weight, capacity):
        self.profit = profit
        self.weight = weight
        self.capacity = capacity

# %%
def decode(chromosome):
    chr = chromosome.tolist()
    return np.array([0 if gen < 0.5 else 1 for gen in chr])

def get_fitness(chromosome, problem : Problem):
    solution = decode(chromosome)
    total_profit = np.sum(solution * problem.profit)
    total_weight = np.sum(solution * problem.weight)
    if total_weight > problem.capacity:
        return 0
    else:
        return total_profit

# %%
class Individual:
    def __init__(self):
        self.chromosome = None
        self.fitness = None

    def gen_indi(self, problem : Problem):
        num_item = problem.profit.size
        self.chromosome = np.random.uniform(0.0, 1.0, num_item)

    def cal_fitness(self, problem : Problem):
        self.fitness = get_fitness(self.chromosome, problem)

    def clone(self):
        return copy.deepcopy(self)

    def __repr__(self):
        return f"chromosome={self.chromosome}, fitness={self.fitness}"

# %%
# Simulated binary crossover - SBX
def crossover(parent1, parent2, problem : Problem, eta = 2.0):
    off1 = Individual()
    off2 = Individual()
    r = np.random.rand()
    if (r <= 0.5):
        beta = (2*r)**(1.0/(eta + 1))
    else:
        beta = (1.0/(2*(1 - r)))**(1.0/(eta + 1))
    p1 = parent1.chromosome
    p2 = parent2.chromosome
    c1 = 0.5 * ((1 + beta) * p1 + (1 - beta) * p2)
    c2 = 0.5 * ((1 - beta) * p1 + (1 + beta) * p2)
    c1 = np.clip(c1, 0.0, 1.0)
    c2 = np.clip(c2, 0.0, 1.0)
    off1.chromosome = c1
    off2.chromosome = c2
    return off1.clone(), off2.clone()

# %%
# Polynomial mutaion - PM
def mutation(indi, eta = 20.0):
    chr = indi.chromosome
    for i in range(chr.size):
        mu = np.random.rand()
        if (mu <= 0.5):
            delta = (2 * mu)**(1.0/(1 + eta)) - 1
            chr[i] = chr[i] + delta * chr[i]
        else:
            delta = 1 - (2 - 2*mu)**(1.0/(1 + eta))
            chr[i] = chr[i] + delta * (1 - chr[i])

    chr = np.clip(chr, 0.0, 1.0)
    indi.chromosome = chr
    return indi.clone()

# %%
class Population:
    def __init__(self, pop_size, problem : Problem):
        self.pop_size = pop_size
        self.list_indi = []
        self.problem = problem

    def genPop(self):
        for i in range(self.pop_size):
            indi = Individual()
            indi.gen_indi(self.problem)
            indi.cal_fitness(self.problem)
            self.list_indi.append(indi)

    def show(self):
        for i in range(len(self.list_indi)):
            print(f"Individual {i}: {self.list_indi[i]}")

# %%
def selection(list, k = 2):
    tour1 = random.sample(list, k)
    tour2 = random.sample(list, k)
    x = max(tour1, key=lambda indi: indi.fitness)
    y = max(tour2, key=lambda indi: indi.fitness)
    return x.clone(), y.clone()

# %%
def survival_selection(list, pop_size):
    list = sorted(list, key=lambda indi: indi.fitness, reverse=True)
    list = list[0: pop_size]
    return list

# %%
def GA(problem, pop_size, max_gen, p_c, p_m):
    pop = Population(pop_size, problem)
    pop.genPop()
    history = []
    for i in range(max_gen):
        child = []
        while (len(child) < pop_size):
            p1, p2 = selection(pop.list_indi)
            if np.random.rand() <= p_c:
                c1, c2 = crossover(p1, p2, problem)
                c1.cal_fitness(problem)
                c2.cal_fitness(problem)
                child.append(c1)
                child.append(c2)
            if np.random.rand() <= p_m:
                p1 = mutation(p1)
                p2 = mutation(p2)
                p1.cal_fitness(problem)
                p2.cal_fitness(problem)
                child.append(p1)
                child.append(p2)
        pop.list_indi = survival_selection(pop.list_indi + child, pop_size)
        history.append(pop.list_indi[0].fitness)
    solution = pop.list_indi[0]
    return history, solution

# %%
# setup
profit = np.array([6.62, 11.21, 16.05, 9.52, 9.22, 10.85, 12.53, 10.95, 17.37, 7.96])
weight = np.array([7.11, 5.44, 10.86, 3.82, 12.96, 8.13, 3.78, 12.49, 13.53, 15.47])
capacity = 65.17
# profit = np.array([3, 6, 8, 10, 15])
# weight = np.array([2, 3, 3, 5, 8])
# capacity = 10
problem = Problem(profit, weight, capacity)

pop_size = 100
max_gen = 500
Pc = 0.8
Pm = 1.0

#start
fitness_history, solution = GA(problem, pop_size, max_gen, Pc, Pm)
# %timeit GA(problem, pop_size, max_gen, Pc, Pm)

#show
for i in range(len(fitness_history)):
    print(f"Generation {i}, bestfitness = {fitness_history[i]:.2f}")
# Out:
# 3.32 s ± 338 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Generation 0, bestfitness = 75.97
# Generation 1, bestfitness = 77.23
# Generation 2, bestfitness = 80.39
# Generation 3, bestfitness = 80.39
# Generation 4, bestfitness = 80.39
# Generation 5, bestfitness = 80.39
# Generation 6, bestfitness = 80.39
# Generation 7, bestfitness = 80.39
# Generation 8, bestfitness = 80.39
# Generation 9, bestfitness = 80.39
# Generation 10, bestfitness = 80.39
# Generation 11, bestfitness = 80.39
# Generation 12, bestfitness = 80.39
# Generation 13, bestfitness = 80.39
# Generation 14, bestfitness = 80.39
# Generation 15, bestfitness = 80.39
# Generation 16, bestfitness = 80.39
# Generation 17, bestfitness = 80.39
# Generation 18, bestfitness = 80.39
# Generation 19, bestfitness = 80.39
# Generation 20, bestfitness = 80.39
# Generation 21, bestfitness = 88.48
# Generation 22, bestfitness = 88.48
# Generation 23, bestfitness = 88.48
# Generation 24, bestfitness = 88.48
# Generation 25, bestfitness = 88.48
# Generation 26, bestfitness = 88.48
# Generation 27, bestfitness = 88.48
# Generation 28, bestfitness = 88.48
# Generation 29, bestfitness = 88.48
# Generation 30, bestfitness = 88.48
# Generation 31, bestfitness = 88.48
# Generation 32, bestfitness = 88.48
# Generation 33, bestfitness = 88.48
# Generation 34, bestfitness = 88.48
# Generation 35, bestfitness = 88.48
# Generation 363, bestfitness = 88.48
# Generation 364, bestfitness = 88.48
# Generation 365, bestfitness = 88.48
# Generation 366, bestfitness = 88.48
# Generation 367, bestfitness = 88.48
# Generation 368, bestfitness = 88.48
# Generation 369, bestfitness = 88.48
# Generation 370, bestfitness = 88.48
# Generation 371, bestfitness = 88.48
# Generation 372, bestfitness = 88.48
# Generation 373, bestfitness = 88.48
# Generation 374, bestfitness = 88.48
# Generation 375, bestfitness = 88.48
# Generation 376, bestfitness = 88.48
# Generation 377, bestfitness = 88.48
# Generation 378, bestfitness = 88.48
# Generation 379, bestfitness = 88.48
# Generation 380, bestfitness = 88.48
# Generation 381, bestfitness = 88.48
# Generation 382, bestfitness = 88.48
# Generation 383, bestfitness = 88.48
# Generation 384, bestfitness = 88.48
# Generation 385, bestfitness = 88.48
# Generation 386, bestfitness = 88.48
# Generation 387, bestfitness = 88.48
# Generation 388, bestfitness = 88.48
# Generation 389, bestfitness = 88.48
# Generation 390, bestfitness = 88.48
# Generation 391, bestfitness = 88.48
# Generation 392, bestfitness = 88.48
# Generation 393, bestfitness = 88.48
# Generation 394, bestfitness = 88.48
# Generation 395, bestfitness = 88.48
# Generation 396, bestfitness = 88.48
# Generation 397, bestfitness = 88.48
# Generation 398, bestfitness = 88.48
# Generation 399, bestfitness = 88.48
# Generation 400, bestfitness = 88.48
# Generation 401, bestfitness = 88.48
# Generation 402, bestfitness = 88.48
# Generation 403, bestfitness = 88.48
# Generation 404, bestfitness = 88.48
# Generation 405, bestfitness = 88.48
# Generation 406, bestfitness = 88.48
# Generation 407, bestfitness = 88.48
# Generation 408, bestfitness = 88.48
# Generation 409, bestfitness = 88.48
# Generation 410, bestfitness = 88.48
# Generation 411, bestfitness = 88.48
# Generation 412, bestfitness = 88.48
# Generation 413, bestfitness = 88.48
# Generation 414, bestfitness = 88.48
# Generation 415, bestfitness = 88.48
# Generation 416, bestfitness = 88.48
# Generation 417, bestfitness = 88.48
# Generation 418, bestfitness = 88.48
# Generation 419, bestfitness = 88.48
# Generation 420, bestfitness = 88.48
# Generation 421, bestfitness = 88.48
# Generation 422, bestfitness = 88.48
# Generation 423, bestfitness = 88.48
# Generation 424, bestfitness = 88.48
# Generation 425, bestfitness = 88.48
# Generation 426, bestfitness = 88.48
# Generation 427, bestfitness = 88.48
# Generation 428, bestfitness = 88.48
# Generation 429, bestfitness = 88.48
# Generation 430, bestfitness = 88.48
# Generation 431, bestfitness = 88.48
# Generation 432, bestfitness = 88.48
# Generation 433, bestfitness = 88.48
# Generation 434, bestfitness = 88.48
# Generation 435, bestfitness = 88.48
# Generation 436, bestfitness = 88.48
# Generation 437, bestfitness = 88.48
# Generation 438, bestfitness = 88.48
# Generation 439, bestfitness = 88.48
# Generation 440, bestfitness = 88.48
# Generation 441, bestfitness = 88.48
# Generation 442, bestfitness = 88.48
# Generation 443, bestfitness = 88.48
# Generation 444, bestfitness = 88.48
# Generation 445, bestfitness = 88.48
# Generation 446, bestfitness = 88.48
# Generation 447, bestfitness = 88.48
# Generation 448, bestfitness = 88.48
# Generation 449, bestfitness = 88.48
# Generation 450, bestfitness = 88.48
# Generation 451, bestfitness = 88.48
# Generation 452, bestfitness = 88.48
# Generation 453, bestfitness = 88.48
# Generation 454, bestfitness = 88.48
# Generation 455, bestfitness = 88.48
# Generation 456, bestfitness = 88.48
# Generation 457, bestfitness = 88.48
# Generation 458, bestfitness = 88.48
# Generation 459, bestfitness = 88.48
# Generation 460, bestfitness = 88.48
# Generation 461, bestfitness = 88.48
# Generation 462, bestfitness = 88.48
# Generation 463, bestfitness = 88.48
# Generation 464, bestfitness = 88.48
# Generation 465, bestfitness = 88.48
# Generation 466, bestfitness = 88.48
# Generation 467, bestfitness = 88.48
# Generation 468, bestfitness = 88.48
# Generation 469, bestfitness = 88.48
# Generation 470, bestfitness = 88.48
# Generation 471, bestfitness = 88.48
# Generation 472, bestfitness = 88.48
# Generation 473, bestfitness = 88.48
# Generation 474, bestfitness = 88.48
# Generation 475, bestfitness = 88.48
# Generation 476, bestfitness = 88.48
# Generation 477, bestfitness = 88.48
# Generation 478, bestfitness = 88.48
# Generation 479, bestfitness = 88.48
# Generation 480, bestfitness = 88.48
# Generation 481, bestfitness = 88.48
# Generation 482, bestfitness = 88.48
# Generation 483, bestfitness = 88.48
# Generation 484, bestfitness = 88.48
# Generation 485, bestfitness = 88.48
# Generation 486, bestfitness = 88.48
# Generation 487, bestfitness = 88.48
# Generation 488, bestfitness = 88.48
# Generation 489, bestfitness = 88.48
# Generation 490, bestfitness = 88.48
# Generation 491, bestfitness = 88.48
# Generation 492, bestfitness = 88.48
# Generation 493, bestfitness = 88.48
# Generation 494, bestfitness = 88.48
# Generation 495, bestfitness = 88.48
# Generation 496, bestfitness = 88.48
# Generation 497, bestfitness = 88.48
# Generation 498, bestfitness = 88.48
# Generation 499, bestfitness = 88.48

# %%
np.set_printoptions(precision=2, suppress=True)
print("problem:")
print(f"profit: {profit}")
print(f"weight: {weight}")
print(f"capacity = {capacity:.2f}")
print()
print("solution:")
print(decode(solution.chromosome))
print(f"total_profit =  {solution.fitness:.2f}")
print(f"total_weight = {np.sum(decode(solution.chromosome) * weight):.2f}")
# Out:
# problem:
# profit: [ 6.62 11.21 16.05  9.52  9.22 10.85 12.53 10.95 17.37  7.96]
# weight: [ 7.11  5.44 10.86  3.82 12.96  8.13  3.78 12.49 13.53 15.47]
# capacity = 65.17
#
# solution:
# [0 1 1 1 0 1 1 1 1 0]
# total_profit =  88.48
# total_weight = 58.05

# %%
generations = list(range(len(fitness_history)))
plt.figure(figsize=(20, 5))
plt.plot(generations, fitness_history, marker='o', linestyle='-', color='b', label='Best Fitness')

plt.xlabel("Generation")
plt.ylabel("Best Fitness")
plt.title("Fitness Progress Over Generations")
plt.legend()
plt.grid(True)
plt.show()
